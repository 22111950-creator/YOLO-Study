# %% [markdown]
# <a href="https://colab.research.google.com/github/22111950-creator/YOLO-Study/blob/COLAB_TEST/classifiy_%ED%95%99%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Jun 21 10:31:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0             27W /   70W |     315MiB /  15360MiB |      4%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1821      C   /usr/bin/python3                        312MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.4/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
from ultralytics import YOLO
rf = Roboflow(api_key="YxAQrthA56eou3zmff0I")
project = rf.workspace("smat-trash-bin").project("smart-trash-bin-aeilx")
dataset = project.version(1).download("folder")

# %%
model = YOLO("yolov8n-cls.pt")
model.train(data=dataset.location, epochs=100, imgsz=320)
# Out:
# /content/{HOME}/datasets
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.5.20)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in smart-trash-bin-1 to folder:: 100%|██████████| 998650/998650 [00:30<00:00, 32233.11it/s]
# Extracting Dataset Version Zip to smart-trash-bin-1 in folder:: 100%|██████████| 12679/12679 [00:05<00:00, 2393.41it/s]
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 175MB/s]
# New https://pypi.org/project/ultralytics/8.4.72 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/content/{HOME}/datasets/smart-trash-bin-1, epochs=100, time=None, patience=100, batch=16, imgsz=320, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/classify/train
# train: /content/{HOME}/datasets/smart-trash-bin-1/train... found 11079 images in 5 classes ✅
# val: None...
# test: /content/{HOME}/datasets/smart-trash-bin-1/test... found 527 images in 4 classes: ERROR ❌️ requires 5 classes, not 4
# Overriding model.yaml nc=1000 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    336645  ultralytics.nn.modules.head.Classify         [256, 5]
# YOLOv8n-cls summary: 99 layers, 1,444,693 parameters, 1,444,693 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 174MB/s]
# AMP: checks passed ✅
# train: Scanning /content/{HOME}/datasets/smart-trash-bin-1/train... 11079 images, 0 corrupt: 100%|██████████| 11079/11079 [00:02<00:00, 5066.95it/s]
# train: New cache created: /content/{HOME}/datasets/smart-trash-bin-1/train.cache
# val: Scanning /content/{HOME}/datasets/smart-trash-bin-1/test... 527 images, 0 corrupt: 100%|██████████| 527/527 [00:00<00:00, 4771.90it/s]
# val: New cache created: /content/{HOME}/datasets/smart-trash-bin-1/test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/classify/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.426G      1.886         16        320:   0%|          | 3/693 [00:01<04:27,  2.58it/s]
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
#       1/100     0.447G      1.868         16        320:   1%|          | 5/693 [00:01<02:56,  3.91it/s]
# 100%|██████████| 755k/755k [00:00<00:00, 35.8MB/s]
#       1/100     0.453G      0.568          7        320: 100%|██████████| 693/693 [02:37<00:00,  4.41it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.54it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.405G     0.1692          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.10it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.411G     0.1243          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.31it/s]
#                    all     0.0133          1
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.411G     0.1164          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.36it/s]
#                    all    0.00759          1
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.403G     0.1021          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.37it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.411G    0.07814          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.68it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.411G    0.06779          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.15it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.411G    0.04856          7        320: 100%|██████████| 693/693 [02:28<00:00,  4.68it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.46it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.403G    0.04622          7        320: 100%|██████████| 693/693 [02:28<00:00,  4.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.28it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.411G    0.03335          7        320: 100%|██████████| 693/693 [02:28<00:00,  4.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.42it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.411G     0.0342          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.36it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.411G     0.0345          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.11it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.403G    0.02566          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.37it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.411G    0.02567          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.23it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.411G    0.02728          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.32it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.411G     0.0273          7        320: 100%|██████████| 693/693 [02:40<00:00,  4.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.96it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.403G    0.02562          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.29it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.411G    0.02619          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.12it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.411G    0.02087          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.31it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.411G    0.02339          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.38it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.403G    0.01832          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.38it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.411G    0.02226          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.24it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.411G    0.02162          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.92it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.411G     0.0174          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.33it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.403G    0.01908          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.24it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.411G    0.01668          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.53it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.411G    0.01804          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.39it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.411G    0.02021          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.43it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.403G    0.01724          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.50it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.411G    0.01926          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.61it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.45it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.411G    0.01415          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.12it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.411G     0.0182          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.50it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      33/100     0.403G    0.01705          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.33it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      34/100     0.411G    0.01612          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.40it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      35/100     0.411G    0.01304          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.12it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      36/100     0.411G    0.01681          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.43it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      37/100     0.403G    0.01339          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.28it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      38/100     0.411G    0.01232          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.34it/s]
#                    all     0.0019          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      39/100     0.411G   0.009126          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.42it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      40/100     0.411G    0.01052          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.37it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      41/100     0.403G    0.01148          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.23it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      42/100     0.411G    0.00968          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.45it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      43/100     0.411G   0.007987          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.31it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      44/100     0.411G   0.009557          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.02it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      45/100     0.403G    0.01034          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.48it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      46/100     0.411G   0.007932          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.27it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      47/100     0.411G    0.01021          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.24it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      48/100     0.411G    0.00905          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.40it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      49/100     0.403G    0.00934          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.41it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      50/100     0.411G    0.01004          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.36it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      51/100     0.411G    0.01077          7        320: 100%|██████████| 693/693 [02:37<00:00,  4.39it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.44it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      52/100     0.411G    0.01037          7        320: 100%|██████████| 693/693 [02:36<00:00,  4.43it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.41it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      53/100     0.403G    0.01204          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.35it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      54/100     0.411G   0.008158          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.42it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      55/100     0.411G   0.006752          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.38it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      56/100     0.411G   0.006852          7        320: 100%|██████████| 693/693 [02:37<00:00,  4.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.40it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      57/100     0.403G   0.008492          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.44it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.40it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      58/100     0.411G   0.007849          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.23it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      59/100     0.411G   0.004613          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.64it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      60/100     0.411G   0.008279          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.52it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      61/100     0.403G   0.007407          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.17it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      62/100     0.411G   0.005894          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.35it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      63/100     0.411G   0.005172          7        320: 100%|██████████| 693/693 [02:30<00:00,  4.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.43it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      64/100     0.411G   0.005229          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.26it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      65/100     0.403G   0.006812          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.05it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      66/100     0.411G   0.005012          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.41it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      67/100     0.411G   0.003971          7        320: 100%|██████████| 693/693 [02:36<00:00,  4.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.12it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      68/100     0.411G   0.005989          7        320: 100%|██████████| 693/693 [02:40<00:00,  4.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.38it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      69/100     0.403G   0.004893          7        320: 100%|██████████| 693/693 [02:38<00:00,  4.36it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.07it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      70/100     0.411G   0.004562          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.46it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      71/100     0.411G   0.003917          7        320: 100%|██████████| 693/693 [02:36<00:00,  4.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.65it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      72/100     0.411G   0.004577          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.31it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      73/100     0.403G    0.00406          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.31it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      74/100     0.411G   0.003596          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.36it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100     0.411G   0.005033          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.30it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100     0.411G   0.003183          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.28it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100     0.403G   0.002567          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.48it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100     0.411G   0.003335          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.45it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100     0.411G   0.004952          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.55it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100     0.411G   0.002657          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.31it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100     0.403G   0.002944          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.52it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100     0.411G   0.002793          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.19it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100     0.411G   0.002424          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.27it/s]
#                    all          0          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100     0.411G   0.003176          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.38it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100     0.403G   0.001896          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.37it/s]
#                    all          0          1
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100     0.411G   0.002353          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.82it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100     0.411G   0.003146          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.56it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100     0.411G   0.003092          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.29it/s]
#                    all     0.0019          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100     0.403G   0.003726          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.25it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100     0.411G   0.003093          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.39it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100     0.411G   0.002318          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.22it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100     0.411G   0.002012          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.16it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100     0.403G   0.002522          7        320: 100%|██████████| 693/693 [02:35<00:00,  4.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.25it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100     0.411G   0.002792          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  4.16it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100     0.411G    0.00186          7        320: 100%|██████████| 693/693 [02:34<00:00,  4.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.28it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100     0.411G   0.001506          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.63it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100     0.403G   0.001618          7        320: 100%|██████████| 693/693 [02:33<00:00,  4.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.24it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100     0.411G   0.001639          7        320: 100%|██████████| 693/693 [02:32<00:00,  4.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:04<00:00,  3.47it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100     0.413G   0.001443          7        320: 100%|██████████| 693/693 [02:31<00:00,  4.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.49it/s]
#                    all     0.0019          1
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100     0.411G    0.00182          7        320: 100%|██████████| 693/693 [02:29<00:00,  4.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:05<00:00,  3.24it/s]
#                    all     0.0019          1
# 100 epochs completed in 4.408 hours.
# Optimizer stripped from runs/classify/train/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train/weights/best.pt, 3.0MB
#
# Validating runs/classify/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1,441,285 parameters, 0 gradients, 3.3 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /content/{HOME}/datasets/smart-trash-bin-1/train... found 11079 images in 5 classes ✅
# val: None...
# test: /content/{HOME}/datasets/smart-trash-bin-1/test... found 527 images in 4 classes: ERROR ❌️ requires 5 classes, not 4
#                classes   top1_acc   top5_acc: 100%|██████████| 17/17 [00:03<00:00,  4.57it/s]
#                    all     0.0133          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train
# Results saved to runs/classify/train
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7804b7751280>
# curves: []
# curves_results: []
# fitness: 0.5066413660533726
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.013282732106745243, 'metrics/accuracy_top5': 1.0, 'fitness': 0.5066413660533726}
# save_dir: PosixPath('runs/classify/train')
# speed: {'preprocess': 0.13833118344620013, 'inference': 0.6637663723621694, 'loss': 0.0003836412809831594, 'postprocess': 0.0003121609479697877}
# task: 'classify'
# top1: 0.013282732106745243
# top5: 1.0

# %%
# !pip install -U onnxscript onnx onnxruntime onnxslim
# Out:
# Collecting onnxscript
#   Downloading onnxscript-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.22.0)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (1.27.0)
# Requirement already satisfied: onnxslim in /usr/local/lib/python3.12/dist-packages (0.1.34)
# Collecting onnxslim
#   Downloading onnxslim-0.1.94-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.26.4)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-0.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.2)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime) (25.12.19)
# Collecting colorama (from onnxslim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: sympy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from onnxslim) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.1->onnxslim) (1.3.0)
# Downloading onnxscript-0.7.0-py3-none-any.whl (714 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 26.5 MB/s eta 0:00:00
# Downloading onnxslim-0.1.94-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 26.0 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.1-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.8/166.8 kB 16.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, onnxslim, onnx_ir, onnxscript
#   Attempting uninstall: onnxslim
#     Found existing installation: onnxslim 0.1.34
#     Uninstalling onnxslim-0.1.34:
#       Successfully uninstalled onnxslim-0.1.34
# Successfully installed colorama-0.4.6 onnx_ir-0.2.1 onnxscript-0.7.0 onnxslim-0.1.94

# %%
from ultralytics import YOLO

model = YOLO("/content/{HOME}/datasets/runs/classify/train/weights/best.pt")

model.export(
    format="onnx",
    imgsz=320,        # classification은 보통 224, 학습 imgsz에 맞추세요
    opset=12,
    simplify=True,
    dynamic=False
)
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon 2.00GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1,441,285 parameters, 0 gradients, 3.3 GFLOPs
#
# PyTorch: starting from '/content/{HOME}/datasets/runs/classify/train/weights/best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 5) (2.8 MB)
# requirements: Ultralytics requirement ['onnxslim==0.1.34'] not found, attempting AutoUpdate...
# Collecting onnxslim==0.1.34
#   Downloading onnxslim-0.1.34-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from onnxslim==0.1.34) (1.22.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxslim==0.1.34) (1.14.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxslim==0.1.34) (26.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim==0.1.34) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim==0.1.34) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim==0.1.34) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim==0.1.34) (0.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxslim==0.1.34) (1.3.0)
# Downloading onnxslim-0.1.34-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: onnxslim
#   Attempting uninstall: onnxslim
#     Found existing installation: onnxslim 0.1.94
#     Uninstalling onnxslim-0.1.94:
#       Successfully uninstalled onnxslim-0.1.94
# Successfully installed onnxslim-0.1.34
#
# requirements: AutoUpdate success ✅ 3.9s, installed 1 package: ['onnxslim==0.1.34']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 12...
# W0621 10:44:46.617000 69330 torch/onnx/_internal/exporter/_compat.py:133] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# /usr/lib/python3.12/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 137, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 132, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /project/onnx/version_converter/adapters/axes_input_to_attribute.h:56: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: export success ✅ 8.4s, saved as '/content/{HOME}/datasets/runs/classify/train/weights/best.onnx' (5.5 MB)
#
# Export complete (8.6s)
# Results saved to /content/{HOME}/datasets/runs/classify/train/weights
# Predict:         yolo predict task=classify model=/content/{HOME}/datasets/runs/classify/train/weights/best.onnx imgsz=320
# Validate:        yolo val task=classify model=/content/{HOME}/datasets/runs/classify/train/weights/best.onnx imgsz=320 data=/content/{HOME}/datasets/smart-trash-bin-1
# Visualize:       https://netron.app
# '/content/{HOME}/datasets/runs/classify/train/weights/best.onnx'

# %%
# !hailo --version
# !hailomz --help
# Out:
# /bin/bash: line 1: hailo: command not found
# /bin/bash: line 1: hailomz: command not found

# %%
# !pip install /content/hailo_dataflow_compiler-*.whl
# !pip install /content/hailo_model_zoo-*.whl
# Out:
# WARNING: Requirement '/content/hailo_dataflow_compiler-*.whl' looks like a filename, but the file does not exist
# ERROR: hailo_dataflow_compiler-*.whl is not a valid wheel filename.
# WARNING: Requirement '/content/hailo_model_zoo-*.whl' looks like a filename, but the file does not exist
# ERROR: hailo_model_zoo-*.whl is not a valid wheel filename.

# %%
# ONNX 변환 및 검증에 필요한 최신 라이브러리 설치
# !pip uninstall ultralytics -y
# !pip install ultralytics==8.0.196
# Out:
# Found existing installation: ultralytics 8.0.196
# Uninstalling ultralytics-8.0.196:
#   Successfully uninstalled ultralytics-8.0.196
# Collecting ultralytics==8.0.196
#   Using cached ultralytics-8.0.196-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (3.10.0)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (0.26.0+cu128)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (4.67.3)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (0.13.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.0.196) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.0.196) (2026.5.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics==8.0.196) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics==8.0.196) (1.5.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.0.196) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (3.0.3)
# Using cached ultralytics-8.0.196-py3-none-any.whl (631 kB)
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.0.196

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.0.196

# %%
# 1. 에러가 발생한 필수 모듈 및 연산자 변환 지원 패키지 설치
# !pip install onnxscript

# 설치가 완료되면 기존 변환 코드를 다시 실행합니다.
# Out:
# Collecting onnxscript
#   Downloading onnxscript-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.26.4)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-0.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting onnx>=1.17 (from onnxscript)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.2)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.17->onnxscript) (5.29.6)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Downloading onnxscript-0.7.0-py3-none-any.whl (714 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 714.8/714.8 kB 14.2 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 58.2 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.1-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.8/166.8 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.21.0 onnx_ir-0.2.1 onnxscript-0.7.0

# %%
# !pip install onnxslim
# Out:
# Collecting onnxslim
#   Downloading onnxslim-0.1.94-py3-none-any.whl.metadata (10 kB)
# Collecting colorama (from onnxslim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from onnxslim) (0.5.4)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from onnxslim) (1.21.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxslim) (26.2)
# Requirement already satisfied: sympy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from onnxslim) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.1->onnxslim) (1.3.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml-dtypes->onnxslim) (1.26.4)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->onnxslim) (4.15.0)
# Downloading onnxslim-0.1.94-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 5.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, onnxslim
# Successfully installed colorama-0.4.6 onnxslim-0.1.94

# %%
import torch
import functools

# 1. PyTorch 보안 우회 패치
torch.load = functools.partial(torch.load, weights_only=False)

from ultralytics import YOLO

# 2. 모델 로드
model = YOLO("/content/{HOME}/datasets/runs/detect/train2/weights/best.pt")

# 3. opset 제한을 우회하기 위해 12 버전으로 지정하여 추출
model.export(
    format="onnx",
    imgsz=640,
    opset=12,          # [수정] 11에서 발생한 Resize 어댑터 에러를 피하기 위해 12로 변경
    simplify=True,     # 그래프 단순화 유지
    dynamic=False,
    nms=False
)
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11127519 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/{HOME}/datasets/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (21.5 MB)
#
# ONNX: starting export with onnx 1.21.0 opset 12...
# W0529 14:53:30.544000 52917 torch/onnx/_internal/exporter/_compat.py:133] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# /usr/lib/python3.12/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 137, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnxscript/version_converter/__init__.py", line 132, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/BaseConverter.h:64: adapter_lookup: Assertion `false` failed: No Adapter To Version $17 for Resize
# ONNX: simplifying with onnxsim v0.6.3...
# ONNX: export success ✅ 5.3s, saved as '/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx' (42.6 MB)
#
# Export complete (7.6s)
# Results saved to /content/{HOME}/datasets/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx imgsz=640 data=/content/{HOME}/datasets/Test-trash-1/data.yaml
# Visualize:       https://netron.app
# '/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx'

# %%
import onnx

# 1. 방금 생성된 ONNX 파일 로드
onnx_model = onnx.load("/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx")

# 2. 메타데이터의 opset 버전을 강제로 12로 패치
for opset in onnx_model.opset_import:
    if opset.domain == '' or opset.domain == 'ai.onnx':
        print(f"기존 버전: {opset.version} -> 변경 버전: 12")
        opset.version = 12

# 3. 변경된 내용을 같은 경로에 덮어쓰기 저장
onnx.save(onnx_model, "/content/{HOME}/datasets/runs/detect/train2/weights/best.onnx")
print("ONNX Opset 버전 강제 변경 완료! 이제 다운로드 하세요. ✅")
# Out:
# 기존 버전: 18 -> 변경 버전: 12
# ONNX Opset 버전 강제 변경 완료! 이제 다운로드 하세요. ✅

# %%
import os
import random
import shutil
from google.colab import files

# [수정된 부분] /content 내부에서 train/images 폴더를 자동으로 검색합니다.
base_path = '/content'
source_dir = None

for root, dirs, files_list in os.walk(base_path):
    if root.endswith('train/images'):
        source_dir = root
        break

if source_dir is None:
    raise FileNotFoundError("Colab 환경 내에서 'train/images' 폴더를 찾을 수 없습니다. 데이터셋 다운로드가 완료되었는지 확인해주세요.")

print(f"찾은 이미지 경로: {source_dir}")

# 2. 랜덤 추출한 이미지를 저장할 새 폴더 생성
target_dir = '/content/calibration_samples'
os.makedirs(target_dir, exist_ok=True)

# 3. 원본 폴더에서 이미지 파일 목록 가져오기
all_images = [f for f in os.listdir(source_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# 4. 설정한 수량만큼 랜덤 추출
sample_count = min(100, len(all_images))
selected_images = random.sample(all_images, sample_count)

print(f"총 {len(all_images)}장의 이미지 중 {sample_count}장을 랜덤 추출합니다.")

# 5. 선택된 이미지를 새 폴더로 복사
for img_name in selected_images:
    source_path = os.path.join(source_dir, img_name)
    target_path = os.path.join(target_dir, img_name)
    shutil.copy(source_path, target_path)

print(f"새 폴더({target_dir})로 복사 완료.")

# 6. 복사된 폴더를 zip 파일로 압축
zip_file_path = '/content/calibration_samples.zip'
shutil.make_archive('/content/calibration_samples', 'zip', target_dir)
print(f"압축 완료: {zip_file_path}")

# 7. 내 PC로 다운로드 실행
print("로컬 다운로드를 시작합니다...")
files.download(zip_file_path)
# Out:
# 찾은 이미지 경로: /content/{HOME}/datasets/Test-trash-1/train/images
# 총 4859장의 이미지 중 100장을 랜덤 추출합니다.
# 새 폴더(/content/calibration_samples)로 복사 완료.
# 압축 완료: /content/calibration_samples.zip
# 로컬 다운로드를 시작합니다...

# %%
import os

# -------------------------------------------------------------
# 업로드하신 5.3.0 버전 파일명으로 정확히 매칭해두었습니다.
# -------------------------------------------------------------
WHL_FILE_NAME = "hailo_dataflow_compiler-5.3.0-py3-none-linux_x86_64.whl"
ONNX_PATH = "/content/best.onnx"
ALLS_PATH = "/content/yolov8s.alls"
CALIB_DIR = "/content/calibration_samples"  # 100장 이미지 추출했던 폴더 경로
MODEL_NAME = "best_yolov8"

# 1. Hailo Dataflow Compiler (DFC) 패키지 설치
print("📦 Hailo DFC 패키지 설치를 시작합니다...")
if os.path.exists(f"/content/{WHL_FILE_NAME}"):
    import subprocess
    # Use subprocess to capture output and check return code for pip install
    result = subprocess.run(["pip", "install", f"/content/{WHL_FILE_NAME}"], capture_output=True, text=True)
    if result.returncode == 0:
        print("✅ DFC 패키지 설치 완료.")
    else:
        print(f"❌ DFC 패키지 설치 실패. 오류: {result.stderr}")
        print("💡 제공된 wheel 파일이 유효하지 않거나 호환되지 않는 것 같습니다.")
        print("   Colab 환경과 호환되는 유효한 'hailo_dataflow_compiler' wheel 파일을 업로드했는지 확인해주세요.")
        raise ModuleNotFoundError("hailo_sdk_client 모듈을 임포트할 수 없습니다. DFC 패키지 설치에 실패했습니다.")
else:
    raise FileNotFoundError(f"❌ /content/{WHL_FILE_NAME} 파일이 아직 Colab에 업로드되지 않았습니다. 업로드 완료 후 다시 실행해주세요.")
print("-" * 50)

# 2. 패키지 로드 및 컴파일러 초기화
from hailo_sdk_client import ClientRunner
import numpy as np
from PIL import Image

runner = ClientRunner(hw_arch="hailo8")

# 3. ONNX 모델 파싱 (HAR 파일 생성)
print("🏗️ ONNX 모델 파싱 중...")
# 내부적으로 같은 폴더에 있는 best.onnx.data 가중치 파일을 자동으로 연동합니다.
runner.translate_onnx_model(
    model_path=ONNX_PATH,
    model_name=MODEL_NAME,
    end_node_names=["output0"]  # YOLOv8 기본 출력 노드명
)
print("✅ 모델 파싱 완료.")

# 4. ALLS 최적화 스크립트 적용
if os.path.exists(ALLS_PATH):
    print("📝 탐색기에서 찾은 최적화 스크립트(yolov8s.alls)를 적용합니다...")
    runner.load_model_script(ALLS_PATH)

# 5. 캘리브레이션 이미지 로드 및 전처리 (INT8 양자화용)
print("🖼️ 캘리브레이션용 이미지 데이터셋 로드 중...")
def load_calibration_data(image_dir, target_size=(640, 640)):
    images = []
    for file in os.listdir(image_dir):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            img = Image.open(os.path.join(image_dir, file)).convert('RGB')
            img = img.resize(target_size)
            img_array = np.array(img).astype(np.float32) / 255.0
            images.append(img_array)
    return np.array(images)

calib_dataset = load_calibration_data(CALIB_DIR)
print(f"✅ 총 {len(calib_dataset)}장의 이미지가 양자화 데이터셋으로 준비되었습니다.")

# 6. 모델 최적화 및 양자화 실행
print("⚡ 모델 양자화(Optimization) 진행 중... (시간이 다소 소요될 수 있습니다)")
runner.optimize(calib_dataset)
print("✅ 양자화 완료.")

# 7. 최종 HEF 파일 컴파일 및 저장
print("🚀 HEF 파일 컴파일 중...")
hef = runner.compile()

output_hef_path = f"/content/{MODEL_NAME}.hef"
with open(output_hef_path, "wb") as f:
    f.write(hef)

print(f"🎉 모든 변환이 성공적으로 완료되었습니다! 파일 경로: {output_hef_path}")

# 8. 내 PC로 최종 결과물 자동 다운로드
from google.colab import files
files.download(output_hef_path)
# Out:
# 📦 Hailo DFC 패키지 설치를 시작합니다...
# ❌ DFC 패키지 설치 실패. 오류:   error: subprocess-exited-with-error
#
#   × Building wheel for pygraphviz (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pygraphviz
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pygraphviz)
#
# 💡 제공된 wheel 파일이 유효하지 않거나 호환되지 않는 것 같습니다.
#    Colab 환경과 호환되는 유효한 'hailo_dataflow_compiler' wheel 파일을 업로드했는지 확인해주세요.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5052/1490612966.py in <cell line: 0>()
#      22         print("💡 제공된 wheel 파일이 유효하지 않거나 호환되지 않는 것 같습니다.")
#      23         print("   Colab 환경과 호환되는 유효한 'hailo_dataflow_compiler' wheel 파일을 업로드했는지 확인해주세요.")
# ---> 24         raise ModuleNotFoundError("hailo_sdk_client 모듈을 임포트할 수 없습니다. DFC 패키지 설치에 실패했습니다.")
#      25 else:
#      26     raise FileNotFoundError(f"❌ /content/{WHL_FILE_NAME} 파일이 아직 Colab에 업로드되지 않았습니다. 업로드 완료 후 다시 실행해주세요.")
#
# ModuleNotFoundError: hailo_sdk_client 모듈을 임포트할 수 없습니다. DFC 패키지 설치에 실패했습니다.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
